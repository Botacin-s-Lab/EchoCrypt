# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
import nltk
import Levenshtein

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/ali/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# make everything bold, comment out if you don't like it
plt.rcParams.update({'font.weight': 'bold', 'axes.labelweight': 'bold', 'axes.titleweight': 'bold'})

# %%
ALPHA = 0.5

# %%
def calculate_levenshtein_accuracy(true_sentence, generated_sentence):
    distance = Levenshtein.distance(true_sentence, generated_sentence)
    max_len = max(len(true_sentence), len(generated_sentence))
    return 1 - (distance / max_len)

def calculate_bleu_score(true_sentence, generated_sentence):
    # Use a smoothing function to avoid BLEU score being zero
    smoothing_function = SmoothingFunction().method1
    return sentence_bleu(
        [true_sentence.split()], 
        generated_sentence.split(), 
        smoothing_function=smoothing_function
    )

def calculate_rouge_scores(true_sentence, generated_sentence):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(true_sentence, generated_sentence)
    rouge_scores = {
        "rouge1": scores['rouge1'].fmeasure,
        "rouge2": scores['rouge2'].fmeasure,
        "rougeL": scores['rougeL'].fmeasure
    }
    return list(rouge_scores.values())

def calculate_meteor_score(true_sentence, generated_sentence):
    # Tokenize sentences
    reference_tokens = true_sentence.split()
    generated_tokens = generated_sentence.split()
    # Calculate METEOR score
    return meteor_score([reference_tokens], generated_tokens)

def combined_score(levenshtein_accuracy, bleu_score, alpha=ALPHA):
    return alpha * levenshtein_accuracy + (1 - alpha) * bleu_score

# %%
# test rouge
true_sentence = "The quick brown fox jumps over the lazy dog"
generated_sentence = "The quick brown fox jumps over the lazy dog"
rouge_scores = calculate_rouge_scores(true_sentence, generated_sentence)
print(rouge_scores)
# Out:
# [1.0, 1.0, 1.0]

# %%
model_map = {
    'base': 'O-CoAtNet',
    'llama3_2_1b': 'LLAMA-3.2-1B',
    'llama3_2_3b': 'LLAMA-3.2-3B',
    'llama3_1_8b': 'LLAMA-3.1-8B',
    'gpt-4o': 'GPT-4o',
    'echocrypt': 'LLAMA-3.2-3B (Fine-tuned)',
}

# %%
main_dir = '.'

# %%
# Data holder for plotting
results = []
file_counter = 0

for model_dir in os.listdir(main_dir):
    model_path = os.path.join(main_dir, model_dir)
    if os.path.isdir(model_path):
        for csv_file in os.listdir(model_path):
            if csv_file.endswith('.csv'):
                csv_path = os.path.join(model_path, csv_file)
                df = pd.read_csv(csv_path)
                nf = float(csv_file.replace('.csv', '').replace('noise_', ''))
                model_name = model_dir
                # Calculate average accuracy for each CSV (noise factor)
                lev_accuracies = []
                bleu_accuracies = []
                for _, row in df.iterrows():
                    true_sentence = row['True Sentence']
                    predicted_sentence = row['Predicted Sentence']
                    llm_sentence = row['LLM Sentence']
                    
                    base_leven = calculate_levenshtein_accuracy(true_sentence, predicted_sentence)
                    base_bleu = calculate_bleu_score(true_sentence, predicted_sentence)
                    base_combined = combined_score(base_leven, base_bleu)
                    base_meteor = calculate_meteor_score(true_sentence, predicted_sentence)
                    base_rouge1, base_rouge2, base_rougeL = calculate_rouge_scores(true_sentence, predicted_sentence)
                    
                    llm_leven = calculate_levenshtein_accuracy(true_sentence, llm_sentence)
                    llm_bleu = calculate_bleu_score(true_sentence, llm_sentence)
                    llm_combined = combined_score(llm_leven, llm_bleu)
                    llm_meteor = calculate_meteor_score(true_sentence, llm_sentence)
                    llm_rouge1, llm_rouge2, llm_rougeL = calculate_rouge_scores(true_sentence, llm_sentence)
                    
                    if file_counter < 3:
                        results.append({
                            'Model': model_map['base'], # CoAtNet
                            'Noise Factor': nf,
                            'Levenshtein Accuracy': base_leven,
                            'BLEU Accuracy': base_bleu,
                            'Meteor Score': base_meteor,
                            'Rouge-1': base_rouge1,
                            'Rouge-2': base_rouge2,
                            'Rouge-L': base_rougeL,
                            'Adjusted Accuracy': base_combined,
                        })
                    
                    results.append({
                        'Model': model_map[model_name], # LLM
                        'Noise Factor': nf,
                        'Levenshtein Accuracy': llm_leven,
                        'BLEU Accuracy': llm_bleu,
                        'Meteor Score': llm_meteor,
                        'Rouge-1': llm_rouge1,
                        'Rouge-2': llm_rouge2,
                        'Rouge-L': llm_rougeL,
                        'Adjusted Accuracy': llm_combined,
                    })
        file_counter += 3

# %%
results_df = pd.DataFrame(results)
# re-order models based on model_map.values()
results_df['Model'] = pd.Categorical(results_df['Model'], model_map.values())
# results_df['Noise Factor'] = results_df['Noise Factor'].astype(str)
results_df
# Out:
#               Model  Noise Factor  Levenshtein Accuracy  BLEU Accuracy  \
# 0         O-CoAtNet         0.024              0.826923       0.031098
# 1      LLAMA-3.2-1B         0.024              1.000000       1.000000
# 2         O-CoAtNet         0.024              0.870968       0.205957
# 3      LLAMA-3.2-1B         0.024              0.021505       0.000000
# 4         O-CoAtNet         0.024              0.841270       0.053077
# ...             ...           ...                   ...            ...
# 17995  LLAMA-3.2-3B         0.012              0.907407       0.643459
# 17996  LLAMA-3.2-3B         0.012              0.932432       0.701688
# 17997  LLAMA-3.2-3B         0.012              0.942308       0.467138
# 17998  LLAMA-3.2-3B         0.012              0.972603       0.880112
# 17999  LLAMA-3.2-3B         0.012              0.978261       0.809107
#
#        Meteor Score   Rouge-1   Rouge-2   Rouge-L  Adjusted Accuracy
# 0          0.198506  0.258065  0.068966  0.258065           0.429010
# 1          0.999878  1.000000  1.000000  1.000000           1.000000
# 2          0.456614  0.518519  0.240000  0.518519           0.538462
# 3          0.000000  0.000000  0.000000  0.000000           0.010753
# 4          0.315625  0.400000  0.111111  0.400000           0.447173
# ...             ...       ...       ...       ...                ...
# 17995      0.841270  0.857143  0.666667  0.857143           0.775433
# 17996      0.905455  0.909091  0.800000  0.909091           0.817060
# 17997      0.778906  0.800000  0.555556  0.800000           0.704723
# 17998      0.899383  0.900000  0.888889  0.900000           0.926357
# 17999      0.855159  0.857143  0.833333  0.857143           0.893684
#
# [18000 rows x 9 columns]

# %%
mean_df = results_df.groupby(['Model', 'Noise Factor']).mean().reset_index()
std_df = results_df.groupby(['Model', 'Noise Factor']).std().reset_index()
# Out:
# /tmp/ipykernel_1529614/2869310711.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = results_df.groupby(['Model', 'Noise Factor']).mean().reset_index()
# /tmp/ipykernel_1529614/2869310711.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   std_df = results_df.groupby(['Model', 'Noise Factor']).std().reset_index()

# %%
mean_df.to_excel('mean.xlsx', index=False)
std_df.to_excel('std.xlsx', index=False)

# %%
mean_df
# Out:
#                         Model  Noise Factor  Levenshtein Accuracy  \
# 0                   O-CoAtNet         0.012              0.954934
# 1                   O-CoAtNet         0.024              0.849667
# 2                   O-CoAtNet         0.060              0.666634
# 3                LLAMA-3.2-1B         0.012              0.906951
# 4                LLAMA-3.2-1B         0.024              0.755460
# 5                LLAMA-3.2-1B         0.060              0.558232
# 6                LLAMA-3.2-3B         0.012              0.969745
# 7                LLAMA-3.2-3B         0.024              0.844219
# 8                LLAMA-3.2-3B         0.060              0.517069
# 9                LLAMA-3.1-8B         0.012              0.978610
# 10               LLAMA-3.1-8B         0.024              0.904196
# 11               LLAMA-3.1-8B         0.060              0.589579
# 12                     GPT-4o         0.012              0.997250
# 13                     GPT-4o         0.024              0.986546
# 14                     GPT-4o         0.060              0.880136
# 15  LLAMA-3.2-3B (Fine-tuned)         0.012              0.996642
# 16  LLAMA-3.2-3B (Fine-tuned)         0.024              0.980217
# 17  LLAMA-3.2-3B (Fine-tuned)         0.060              0.864653
#
#     BLEU Accuracy  Meteor Score   Rouge-1   Rouge-2   Rouge-L  \
# 0        0.382687      0.640261  0.690445  0.497464  0.690445
# 1        0.078292      0.285578  0.373621  0.131358  0.373621
# 2        0.020829      0.082084  0.141094  0.017019  0.141094
# 3        0.684136      0.829666  0.843997  0.753865  0.843509
# 4        0.272778      0.504091  0.552086  0.361365  0.550102
# 5        0.041068      0.137256  0.195977  0.058535  0.194066
# 6        0.862792      0.941060  0.943644  0.898633  0.943417
# 7        0.541753      0.751380  0.777061  0.629015  0.776414
# 8        0.117851      0.343862  0.405937  0.190513  0.399777
# 9        0.909638      0.963748  0.964181  0.931836  0.962988
# 10       0.680958      0.845528  0.856259  0.748302  0.855565
# 11       0.188858      0.453530  0.502666  0.284863  0.496949
# 12       0.974563      0.988421  0.989017  0.978678  0.989017
# 13       0.916487      0.958355  0.959970  0.924980  0.959970
# 14       0.637890      0.804067  0.816563  0.703146  0.816163
# 15       0.977157      0.989888  0.990125  0.981812  0.990125
# 16       0.907828      0.959678  0.960321  0.926835  0.960246
# 17       0.622930      0.806560  0.815124  0.701053  0.813948
#
#     Adjusted Accuracy
# 0            0.668811
# 1            0.463979
# 2            0.343732
# 3            0.795543
# 4            0.514119
# 5            0.299650
# 6            0.916268
# 7            0.692986
# 8            0.317460
# 9            0.944124
# 10           0.792577
# 11           0.389218
# 12           0.985907
# 13           0.951516
# 14           0.759013
# 15           0.986899
# 16           0.944023
# 17           0.743792

# %%
df = mean_df.copy()
df2 = std_df.copy()

# Map Noise Factor to corresponding levels
noise_levels = {0.012: "Low", 0.024: "Mid", 0.06: "High"}
bold_model = "GPT-4o"
df["Noise Level"] = df["Noise Factor"].map(noise_levels)
df2["Noise Level"] = df2["Noise Factor"].map(noise_levels)

# Generate LaTeX table rows
def generate_latex_rows(df, std_df, metric_columns):
    latex_rows = []
    for metric in metric_columns:
        for noise_level in ["Low", "Mid", "High"]:
            subset = df[(df["Noise Level"] == noise_level)]
            subset_std = std_df[(std_df["Noise Level"] == noise_level)]
           
            row = f"        {metric} ({noise_level}) & " + " & ".join(
                f"{mean:.3f} $\\pm$ {std:.3f}" for mean, std in zip(subset[metric], subset_std[metric])
            ) + " \\\\"
            latex_rows.append(row)
        latex_rows.append("\midrule")
    return "\n".join(latex_rows)

# Specify metric columns
metric_columns = ["BLEU Accuracy", "Meteor Score", "Rouge-1", "Rouge-2", "Rouge-L"]

# Generate LaTeX rows for the specified metrics
latex_rows = generate_latex_rows(df, df2, metric_columns)

# Print the rows
print(latex_rows)
# Out:
#         BLEU Accuracy (Low) & 0.383 $\pm$ 0.249 & 0.684 $\pm$ 0.294 & 0.863 $\pm$ 0.183 & 0.910 $\pm$ 0.159 & 0.975 $\pm$ 0.075 & 0.977 $\pm$ 0.073 \\
#         BLEU Accuracy (Mid) & 0.078 $\pm$ 0.091 & 0.273 $\pm$ 0.268 & 0.542 $\pm$ 0.282 & 0.681 $\pm$ 0.258 & 0.916 $\pm$ 0.120 & 0.908 $\pm$ 0.156 \\
#         BLEU Accuracy (High) & 0.021 $\pm$ 0.023 & 0.041 $\pm$ 0.083 & 0.118 $\pm$ 0.151 & 0.189 $\pm$ 0.196 & 0.638 $\pm$ 0.287 & 0.623 $\pm$ 0.302 \\
# \midrule
#         Meteor Score (Low) & 0.640 $\pm$ 0.190 & 0.830 $\pm$ 0.213 & 0.941 $\pm$ 0.084 & 0.964 $\pm$ 0.070 & 0.988 $\pm$ 0.032 & 0.990 $\pm$ 0.032 \\
#         Meteor Score (Mid) & 0.286 $\pm$ 0.162 & 0.504 $\pm$ 0.273 & 0.751 $\pm$ 0.184 & 0.846 $\pm$ 0.143 & 0.958 $\pm$ 0.057 & 0.960 $\pm$ 0.073 \\
#         Meteor Score (High) & 0.082 $\pm$ 0.085 & 0.137 $\pm$ 0.159 & 0.344 $\pm$ 0.211 & 0.454 $\pm$ 0.219 & 0.804 $\pm$ 0.189 & 0.807 $\pm$ 0.191 \\
# \midrule
#         Rouge-1 (Low) & 0.690 $\pm$ 0.157 & 0.844 $\pm$ 0.194 & 0.944 $\pm$ 0.080 & 0.964 $\pm$ 0.071 & 0.989 $\pm$ 0.032 & 0.990 $\pm$ 0.034 \\
#         Rouge-1 (Mid) & 0.374 $\pm$ 0.148 & 0.552 $\pm$ 0.249 & 0.777 $\pm$ 0.159 & 0.856 $\pm$ 0.129 & 0.960 $\pm$ 0.055 & 0.960 $\pm$ 0.071 \\
#         Rouge-1 (High) & 0.141 $\pm$ 0.113 & 0.196 $\pm$ 0.173 & 0.406 $\pm$ 0.196 & 0.503 $\pm$ 0.200 & 0.817 $\pm$ 0.171 & 0.815 $\pm$ 0.176 \\
# \midrule
#         Rouge-2 (Low) & 0.497 $\pm$ 0.226 & 0.754 $\pm$ 0.251 & 0.899 $\pm$ 0.137 & 0.932 $\pm$ 0.121 & 0.979 $\pm$ 0.061 & 0.982 $\pm$ 0.060 \\
#         Rouge-2 (Mid) & 0.131 $\pm$ 0.136 & 0.361 $\pm$ 0.276 & 0.629 $\pm$ 0.240 & 0.748 $\pm$ 0.209 & 0.925 $\pm$ 0.103 & 0.927 $\pm$ 0.123 \\
#         Rouge-2 (High) & 0.017 $\pm$ 0.050 & 0.059 $\pm$ 0.122 & 0.191 $\pm$ 0.190 & 0.285 $\pm$ 0.214 & 0.703 $\pm$ 0.244 & 0.701 $\pm$ 0.254 \\
# \midrule
#         Rouge-L (Low) & 0.690 $\pm$ 0.157 & 0.844 $\pm$ 0.194 & 0.943 $\pm$ 0.080 & 0.963 $\pm$ 0.073 & 0.989 $\pm$ 0.032 & 0.990 $\pm$ 0.034 \\
#         Rouge-L (Mid) & 0.374 $\pm$ 0.148 & 0.550 $\pm$ 0.249 & 0.776 $\pm$ 0.160 & 0.856 $\pm$ 0.130 & 0.960 $\pm$ 0.055 & 0.960 $\pm$ 0.071 \\
#         Rouge-L (High) & 0.141 $\pm$ 0.113 & 0.194 $\pm$ 0.172 & 0.400 $\pm$ 0.196 & 0.497 $\pm$ 0.202 & 0.816 $\pm$ 0.172 & 0.814 $\pm$ 0.179 \\
# \midrule

# %%
noise_values = list(noise_levels.keys())
noise_lables = list(noise_levels.values())
print(noise_values)
print(noise_lables)
# Out:
# [0.012, 0.024, 0.06]
# ['Low', 'Mid', 'High']

# %%
import math 

models = mean_df["Model"].unique()
print(models)
plt.figure(figsize=(6, 6))

for model in models:
    mean_subset = mean_df[mean_df["Model"] == model]
    std_subset = std_df[std_df["Model"] == model]
    
    # Extracting values and ensuring alignment
    x_values = mean_subset["Noise Factor"].values
    y_mean = mean_subset["BLEU Accuracy"].values
    # y_std = std_subset["BLEU Accuracy"].values 
    y_std = 0
    
    # Calculating bounds
    lower_bound = y_mean - y_std
    upper_bound = y_mean + y_std
    
    # Plotting mean line
    plt.plot(x_values, y_mean, marker='o', label=model)
    
    # Adding shaded area
    plt.fill_between(x_values, lower_bound, upper_bound, alpha=0.2)

plt.title("Phone: BLEU")
plt.xlabel("Noise Factor")
plt.xticks(noise_values, labels=noise_lables)
plt.ylabel("BLEU values")
plt.legend()
plt.grid(True)
plt.savefig("BLEU_Accuracy_phone.pdf")
plt.show()
# Out:
# ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']
# Categories (6, object): ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']

# %%
import math 

models = mean_df["Model"].unique()
print(models)
plt.figure(figsize=(6, 6))

for model in models:
    mean_subset = mean_df[mean_df["Model"] == model]
    std_subset = std_df[std_df["Model"] == model]
    
    # Extracting values and ensuring alignment
    x_values = mean_subset["Noise Factor"].values
    y_mean = mean_subset["Meteor Score"].values
    # y_std = std_subset["BLEU Accuracy"].values 
    y_std = 0
    
    # Calculating bounds
    lower_bound = y_mean - y_std
    upper_bound = y_mean + y_std
    
    # Plotting mean line
    plt.plot(x_values, y_mean, marker='o', label=model)
    
    # Adding shaded area
    plt.fill_between(x_values, lower_bound, upper_bound, alpha=0.2)

plt.title("Phone: METEOR")
plt.xlabel("Noise Factor")
plt.xticks(noise_values, labels=noise_lables)
plt.ylabel("METEOR values")
plt.legend()
plt.grid(True)
plt.savefig("Meteor_Score_phone.pdf")
plt.show()
# Out:
# ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']
# Categories (6, object): ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']

# %%
import math 

models = mean_df["Model"].unique()
print(models)
plt.figure(figsize=(6, 6))

for model in models:
    mean_subset = mean_df[mean_df["Model"] == model]
    std_subset = std_df[std_df["Model"] == model]
    
    # Extracting values and ensuring alignment
    x_values = mean_subset["Noise Factor"].values
    y_mean = mean_subset["Rouge-1"].values
    # y_std = std_subset["BLEU Accuracy"].values 
    y_std = 0
    
    # Calculating bounds
    lower_bound = y_mean - y_std
    upper_bound = y_mean + y_std
    
    # Plotting mean line
    plt.plot(x_values, y_mean, marker='o', label=model)
    
    # Adding shaded area
    plt.fill_between(x_values, lower_bound, upper_bound, alpha=0.2)

plt.title("Phone: Rouge-1")
plt.xlabel("Noise Factor")
plt.xticks(noise_values, labels=noise_lables)
plt.ylabel("Rouge-1 values")
plt.legend()
plt.grid(True)
plt.savefig("Rouge_1_phone.pdf")
plt.show()
# Out:
# ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']
# Categories (6, object): ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']

# %%
import math 

models = mean_df["Model"].unique()
print(models)
plt.figure(figsize=(6, 6))

for model in models:
    mean_subset = mean_df[mean_df["Model"] == model]
    std_subset = std_df[std_df["Model"] == model]
    
    # Extracting values and ensuring alignment
    x_values = mean_subset["Noise Factor"].values
    y_mean = mean_subset["Rouge-2"].values
    # y_std = std_subset["BLEU Accuracy"].values 
    y_std = 0
    
    # Calculating bounds
    lower_bound = y_mean - y_std
    upper_bound = y_mean + y_std
    
    # Plotting mean line
    plt.plot(x_values, y_mean, marker='o', label=model)
    
    # Adding shaded area
    plt.fill_between(x_values, lower_bound, upper_bound, alpha=0.2)

plt.title("Phone: Rouge-2")
plt.xlabel("Noise Factor")
plt.xticks(noise_values, labels=noise_lables)
plt.ylabel("Rouge-2 values")
plt.legend()
plt.grid(True)
plt.savefig("Rouge_2_phone.pdf")
plt.show()
# Out:
# ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']
# Categories (6, object): ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']

# %%
import math 

models = mean_df["Model"].unique()
print(models)
plt.figure(figsize=(6, 6))

for model in models:
    mean_subset = mean_df[mean_df["Model"] == model]
    std_subset = std_df[std_df["Model"] == model]
    
    # Extracting values and ensuring alignment
    x_values = mean_subset["Noise Factor"].values
    y_mean = mean_subset["Rouge-L"].values
    # y_std = std_subset["BLEU Accuracy"].values 
    y_std = 0
    
    # Calculating bounds
    lower_bound = y_mean - y_std
    upper_bound = y_mean + y_std
    
    # Plotting mean line
    plt.plot(x_values, y_mean, marker='o', label=model)
    
    # Adding shaded area
    plt.fill_between(x_values, lower_bound, upper_bound, alpha=0.2)

plt.title("Phone: Rouge-L")
plt.xlabel("Noise Factor")
plt.xticks(noise_values, labels=noise_lables)
plt.ylabel("Rouge-L values")
plt.legend()
plt.grid(True)
plt.savefig("Rouge_L_phone.pdf")
plt.show()
# Out:
# ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']
# Categories (6, object): ['O-CoAtNet', 'LLAMA-3.2-1B', 'LLAMA-3.2-3B', 'LLAMA-3.1-8B', 'GPT-4o', 'LLAMA-3.2-3B (Fine-tuned)']
