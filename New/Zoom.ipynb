# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import librosa
import os
import random
import seaborn as sns
import pandas as pd
import pickle

from tqdm import tqdm
from torchvision import datasets, transforms
from collections import defaultdict
from torchvision.transforms import Compose, ToTensor
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from scipy.io import wavfile
from functools import reduce
from sklearn import metrics 
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ### Init

# %%
IMAGE_SIZE = 64
NUM_CLASSES = 36 # 26 + 10
BATCH_SIZE = 16
LEARNING_RATE = 5e-4
WEIGHT_DECAY = 1e-1
EPOCHS = 1100

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("device:", DEVICE)
# Out:
# device: cuda

# %% [markdown]
# ### Pre-processing

# %%
def isolator(signal, sample_rate, size, scan, before, after, threshold, show=False):
    strokes = []
    # -- signal'
    if show:
        plt.figure(figsize=(7, 2))
        librosa.display.waveshow(signal, sr=sample_rate)
    fft = librosa.stft(signal, n_fft=size, hop_length=scan)
    energy = np.abs(np.sum(fft, axis=0)).astype(float)
    # norm = np.linalg.norm(energy)
    # energy = energy/norm
    # -- energy'
    if show:
        plt.figure(figsize=(7, 2))
        librosa.display.waveshow(energy)
    threshed = energy > threshold
    # -- peaks'
    if show:
        plt.figure(figsize=(7, 2))
        librosa.display.waveshow(threshed.astype(float))
    peaks = np.where(threshed == True)[0]
    peak_count = len(peaks)
    prev_end = sample_rate*0.1*(-1)
    # '-- isolating keystrokes'
    for i in range(peak_count):
        this_peak = peaks[i]
        timestamp = (this_peak*scan) + size//2
        if timestamp > prev_end + (0.1*sample_rate):
            keystroke = signal[timestamp-before:timestamp+after]
            strokes.append(torch.tensor(keystroke)[None, :])
            if show:
                plt.figure(figsize=(7, 2))
                librosa.display.waveshow(keystroke, sr=sample_rate)
            prev_end = timestamp+after
    return strokes

# %%
AUDIO_FILE = '../dataset/Zoom/'
keys_s = '1234567890qwertyuiopasdfghjklzxcvbnm'
labels = list(keys_s)
keys = [k + '.wav' for k in labels]
data_dict = {'Key':[], 'File':[]}

for i, File in tqdm(enumerate(keys)):
    loc = AUDIO_FILE + File
    samples, sample_rate = librosa.load(loc, sr=None)
    #samples = samples[round(1*sample_rate):]
    strokes = []
    prom = 0.06
    step = 0.005
    while not len(strokes) == 25:
        strokes = isolator(samples[1*sample_rate:], sample_rate, 48, 24, 2400, 12000, prom, False)
        if len(strokes) < 25:
            prom -= step
        if len(strokes) > 25:
            prom += step
        if prom <= 0:
            print('-- not possible for: ',File)
            break
        step = step*0.99
    label = [labels[i]]*len(strokes)
    data_dict['Key'] += label
    data_dict['File'] += strokes

df = pd.DataFrame(data_dict)
mapper = {}
counter = 0
for l in df['Key']:
    if not l in mapper:
        mapper[l] = counter
        counter += 1
df.replace({'Key': mapper}, inplace=True)

# %%
print("Sample Rate --> \n", sample_rate)
sr = sample_rate
print("-"*50)
print("data_frame.head() --> \n", df.head())
print("-"*50)
print("data_frame.info() --> \n", df.info())
# Out:
# Sample Rate -->
#  32000
# --------------------------------------------------
# data_frame.head() -->
#    Key                                               File
# 0   0  [[tensor(0.), tensor(0.), tensor(0.), tensor(0...
# 1   0  [[tensor(0.), tensor(0.), tensor(0.), tensor(0...
# 2   0  [[tensor(0.), tensor(0.), tensor(0.), tensor(0...
# 3   0  [[tensor(0.), tensor(0.), tensor(0.), tensor(0...
# 4   0  [[tensor(0.), tensor(0.), tensor(0.), tensor(0...
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Key     900 non-null    object
#  1   File    900 non-null    object
# dtypes: object(2)
# memory usage: 14.2+ KB
# data_frame.info() -->
#  None

# %% [markdown]
# ### Start Training

# %%
train, test = train_test_split(df, test_size=0.2)
print(len(train))
print(len(test))
# Out:
# 720
# 180

# %%
class MyDataset(Dataset):
    def __init__(self, file_name, transform = None, aug = None):
        df = file_name
        self.transform = transform
        self.aug = aug
        self.labels = df['Key']
        self.values = df['File']
        
    def __len__(self):
        return len(self.labels)
    def __getitem__(self, index):
        label = self.labels.iloc[index]
        value = self.values.iloc[index]
        waveform = self.values.iloc[index]
        label = self.labels.iloc[index]
        if self.transform:
            waveform = waveform.numpy()
            waveform = waveform.flatten()
            waveform = self.transform(waveform)
        if self.aug:
            waveform = self.aug(waveform)
        return waveform, label

class ToMelSpectrogram:
    def __call__(self, samples):
#         samples = np.array(samples)
        spec = librosa.feature.melspectrogram(y = samples, sr = sr, n_mels=64, n_fft=1024, hop_length=500)
        return librosa.power_to_db(spec)

class TimeShifting():
    def __call__(self, samples):
        samples = samples.numpy()
        samples = samples.flatten()
        
        shift = int(len(samples) * 0.4)
        random_shift =random.randint(0, shift)
        data_roll = np.roll(samples, random_shift)
        return data_roll
    
class SpecAugment():
    def __call__(self, samples):
        num_mask = 2
        freq_masking_max_percentage=0.10
        time_masking_max_percentage=0.10
        spec = samples.copy()
        mean_value = spec.mean()
        for i in range(num_mask):
            all_frames_num, all_freqs_num = spec.shape[1], spec.shape[1] 
            freq_percentage = random.uniform(0.0, freq_masking_max_percentage)

            num_freqs_to_mask = int(freq_percentage * all_freqs_num)
            f0 = np.random.uniform(low=0.0, high=all_freqs_num - num_freqs_to_mask)
            f0 = int(f0)
            spec[:, f0:f0 + num_freqs_to_mask] = mean_value

            time_percentage = random.uniform(0.0, time_masking_max_percentage)

            num_frames_to_mask = int(time_percentage * all_frames_num)
            t0 = np.random.uniform(low=0.0, high=all_frames_num - num_frames_to_mask)
            t0 = int(t0)
            spec[t0:t0 + num_frames_to_mask, :] = mean_value
        return spec

aug = Compose([
    TimeShifting(),
    ToMelSpectrogram(),
    SpecAugment(),
    ToTensor()
    ])

transform = Compose([
    ToMelSpectrogram(),
    ToTensor()])

# %%
train_dataset = MyDataset(train, aug = aug)
val_dataset = MyDataset(test, transform = transform)
train_loader = DataLoader(train_dataset,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_dataset,batch_size=BATCH_SIZE, shuffle=True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.imshow(train_dataset[0][0][0], cmap='viridis')

# %%
result_dict = {'epochs':[], 'train_data_loss':[], "train_data_acc":[], 'val_data_acc':[], 'val_data_loss':[]}

# %% [markdown]
# ### Model

# %%
def init_linear(m):
    if isinstance(m, (nn.Conv2d, nn.Linear)):
        nn.init.kaiming_normal_(m.weight)
        if m.bias is not None: nn.init.zeros_(m.bias)

class Partial:
    def __init__(self, module, *args, **kwargs):
        self.module = module
        self.args = args
        self.kwargs = kwargs

    def __call__(self, *args_c, **kwargs_c):
        return self.module(*args_c, *self.args, **kwargs_c, **self.kwargs)

class LayerNormChannels(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.norm = nn.LayerNorm(channels)
    
    def forward(self, x):
        x = x.transpose(1, -1)
        x = self.norm(x)
        x = x.transpose(-1, 1)
        return x
    
class Residual(nn.Module):
    def __init__(self, *layers, shortcut=None):
        super().__init__()
        self.shortcut = nn.Identity() if shortcut is None else shortcut
        self.residual = nn.Sequential(*layers)
        self.gamma = nn.Parameter(torch.zeros(1))
    
    def forward(self, x):
        return self.shortcut(x) + self.gamma * self.residual(x)
    
class ConvBlock(nn.Sequential):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, groups=1):
        padding = (kernel_size - 1) // 2
        super().__init__(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride=stride, padding=padding,
                      groups=groups, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.GELU()
        )
        
def get_shortcut(in_channels, out_channels, stride):
    if (in_channels == out_channels and stride == 1):
        shortcut = nn.Identity()
    else:
        shortcut = nn.Conv2d(in_channels, out_channels, 1)

    if stride > 1:
        shortcut = nn.Sequential(nn.MaxPool2d(stride), shortcut)
    
    return shortcut

class SqueezeExciteBlock(nn.Module):
    def __init__(self, channels, reduction=4):
        super().__init__()
        self.out_channels = channels
        channels_r = channels // reduction
        self.se = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(channels, channels_r, kernel_size=1),
            nn.GELU(),
            nn.Conv2d(channels_r, channels, kernel_size=1),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        return x * self.se(x)
    
class MBConv(Residual):
    def __init__(self, in_channels, out_channels, shape, kernel_size=3, stride=1, expansion_factor=4):
        mid_channels = in_channels * expansion_factor
        super().__init__(
            nn.BatchNorm2d(in_channels),
            nn.GELU(),
            ConvBlock(in_channels, mid_channels, 1), # Pointwise
            ConvBlock(mid_channels, mid_channels, kernel_size, stride=stride, groups=mid_channels), # Depthwise
            SqueezeExciteBlock(mid_channels),
            nn.Conv2d(mid_channels, out_channels, 1), # Pointwise
            shortcut = get_shortcut(in_channels, out_channels, stride)
        )

class SelfAttention2d(nn.Module):
    def __init__(self, in_channels, out_channels, head_channels, shape, p_drop=0.):
        super().__init__()
        self.heads = out_channels // head_channels
        self.head_channels = head_channels
        self.scale = head_channels**-0.5
        
        self.to_keys = nn.Conv2d(in_channels, out_channels, 1)
        self.to_queries = nn.Conv2d(in_channels, out_channels, 1)
        self.to_values = nn.Conv2d(in_channels, out_channels, 1)
        self.unifyheads = nn.Conv2d(out_channels, out_channels, 1)
        
        height, width = shape
        self.pos_enc = nn.Parameter(torch.randn(self.heads, (2 * height - 1) * (2 * width - 1)))
        self.register_buffer("relative_indices", self.get_indices(height, width))

        self.drop = nn.Dropout(p_drop)
    
    def forward(self, x):
        b, _, h, w = x.shape
        
        keys = self.to_keys(x).view(b, self.heads, self.head_channels, -1)
        values = self.to_values(x).view(b, self.heads, self.head_channels, -1)
        queries = self.to_queries(x).view(b, self.heads, self.head_channels, -1)
        
        att = keys.transpose(-2, -1) @ queries
        
        indices = self.relative_indices.expand(self.heads, -1)
        rel_pos_enc = self.pos_enc.gather(-1, indices)
        rel_pos_enc = rel_pos_enc.unflatten(-1, (h * w, h * w))
        
        att = att * self.scale + rel_pos_enc
        att = F.softmax(att, dim=-2)
        
        out = values @ att
        out = out.view(b, -1, h, w)
        out = self.unifyheads(out)
        out = self.drop(out)
        return out
    
    @staticmethod
    def get_indices(h, w):
        y = torch.arange(h, dtype=torch.long)
        x = torch.arange(w, dtype=torch.long)
        
        y1, x1, y2, x2 = torch.meshgrid(y, x, y, x)
        indices = (y1 - y2 + h - 1) * (2 * w - 1) + x1 - x2 + w - 1
        indices = indices.flatten()
        
        return indices
    
class FeedForward(nn.Sequential):
    def __init__(self, in_channels, out_channels, mult=4, p_drop=0.):
        hidden_channels = in_channels * mult
        super().__init__(
            nn.Conv2d(in_channels, hidden_channels, 1),
            nn.GELU(),
            nn.Conv2d(hidden_channels, out_channels, 1),
            nn.Dropout(p_drop)
        )

class TransformerBlock(nn.Sequential):
    def __init__(self, in_channels, out_channels, head_channels, shape, stride=1, p_drop=0.):
        shape = (shape[0] // stride, shape[1] // stride)
        super().__init__(
            Residual(
                LayerNormChannels(in_channels),
                nn.MaxPool2d(stride) if stride > 1 else nn.Identity(),
                SelfAttention2d(in_channels, out_channels, head_channels, shape, p_drop=p_drop),
                shortcut = get_shortcut(in_channels, out_channels, stride)
            ),
            Residual(
                LayerNormChannels(out_channels),
                FeedForward(out_channels, out_channels, p_drop=p_drop)
            )
        )

class Stem(nn.Sequential):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__(
            ConvBlock(in_channels, out_channels, 3, stride=stride),
            nn.Conv2d(out_channels, out_channels, 3, padding=1)
        )

class Head(nn.Sequential):
    def __init__(self, channels, classes, p_drop=0.):
        super().__init__(
            LayerNormChannels(channels),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Dropout(p_drop),
            nn.Linear(channels, classes)
        )

class BlockStack(nn.Sequential):
    def __init__(self, num_blocks, shape, in_channels, out_channels, stride, block):
        layers = []
        for _ in range(num_blocks):
            layers.append(block(in_channels, out_channels, shape=shape, stride=stride))
            shape = (shape[0] // stride, shape[1] // stride)
            in_channels = out_channels
            stride=1
        super().__init__(*layers)

class CoAtNet(nn.Sequential):
    def __init__(self, classes, image_size, head_channels, channel_list, num_blocks, strides=None,
                 in_channels=1, trans_p_drop=0., head_p_drop=0.):
        if strides is None: strides = [2] * len(num_blocks)
        
        block_list = [MBConv,    # S1
                      MBConv,    # S2
                      Partial(TransformerBlock, head_channels, p_drop=trans_p_drop), # S3
                      Partial(TransformerBlock, head_channels, p_drop=trans_p_drop)] # S4
        
        layers = [Stem(in_channels, channel_list[0], strides[0])] # S0
        in_channels = channel_list[0]
        
        shape = (image_size, image_size)
        for num, out_channels, stride, block in zip(num_blocks, channel_list[1:], strides[1:], block_list):
            layers.append(BlockStack(num, shape, in_channels, out_channels, stride, block))
            shape = (shape[0] // stride, shape[1] // stride)
            in_channels = out_channels
            
        layers.append(Head(in_channels, classes, p_drop=head_p_drop))
        super().__init__(*layers)

# %%
def separate_parameters(model):
    parameters_decay = set()
    parameters_no_decay = set()
    modules_weight_decay = (nn.Linear, nn.Conv2d)
    modules_no_weight_decay = (nn.LayerNorm, nn.BatchNorm2d)
    
    for m_name, m in model.named_modules():
        for param_name, param in m.named_parameters():
            full_param_name = f"{m_name}.{param_name}" if m_name else param_name

            if isinstance(m, modules_no_weight_decay):
                parameters_no_decay.add(full_param_name)
            elif param_name.endswith("bias"):
                parameters_no_decay.add(full_param_name)
            elif isinstance(m, Residual) and param_name.endswith("gamma"):
                parameters_no_decay.add(full_param_name)
            elif isinstance(m, SelfAttention2d) and param_name.endswith("pos_enc"):
                parameters_no_decay.add(full_param_name)
            elif isinstance(m, modules_weight_decay):
                parameters_decay.add(full_param_name)
    
    # sanity check
    assert len(parameters_decay & parameters_no_decay) == 0
    assert len(parameters_decay) + len(parameters_no_decay) == len(list(model.parameters()))

    return parameters_decay, parameters_no_decay

def get_optimizer(model, learning_rate, weight_decay):
    param_dict = {pn: p for pn, p in model.named_parameters()}
    parameters_decay, parameters_no_decay = separate_parameters(model)
    
    optim_groups = [
        {"params": [param_dict[pn] for pn in parameters_decay], "weight_decay": weight_decay},
        {"params": [param_dict[pn] for pn in parameters_no_decay], "weight_decay": 0.0},
    ]
    optimizer = optim.AdamW(optim_groups, lr=learning_rate)
    return optimizer

def print_res():
    plt.figure(figsize=(12, 4))
    plt.subplot(1,2,1)
    plt.title("train loss")
    
    plt.plot(list(result_dict['train_data_loss']))
    plt.plot(list(result_dict['val_data_loss']))
    plt.legend(["train loss", "val loss"], loc =  "best")
    plt.subplot(1,2,2)
    plt.plot(list(result_dict['train_data_acc']))
    plt.plot(list(result_dict['val_data_acc']))
    plt.legend(["train acc", "val acc"], loc =  "best")
    plt.show()

# %%
MODEL_PATH = "CoAtNet_Zoom_36.pkl" 

model = CoAtNet(NUM_CLASSES, IMAGE_SIZE, head_channels=32, channel_list=[64, 64, 128, 256, 512],
                num_blocks=[2, 2, 2, 2, 2], strides=[1, 1, 2, 2, 2],
                trans_p_drop=0.3, head_p_drop=0.3)
model.to(DEVICE)
model.apply(init_linear)
# Out:
# c:\Users\user\miniconda3\Lib\site-packages\torch\functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# CoAtNet(
#   (0): Stem(
#     (0): ConvBlock(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#     )
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (1): BlockStack(
#     (0): MBConv(
#       (shortcut): Identity()
#       (residual): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): GELU(approximate='none')
#         (2): ConvBlock(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (3): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (4): SqueezeExciteBlock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (2): GELU(approximate='none')
#             (3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (5): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): MBConv(
#       (shortcut): Identity()
#       (residual): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): GELU(approximate='none')
#         (2): ConvBlock(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (3): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (4): SqueezeExciteBlock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (2): GELU(approximate='none')
#             (3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (5): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (2): BlockStack(
#     (0): MBConv(
#       (shortcut): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (residual): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): GELU(approximate='none')
#         (2): ConvBlock(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (3): ConvBlock(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (4): SqueezeExciteBlock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (2): GELU(approximate='none')
#             (3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (5): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): MBConv(
#       (shortcut): Identity()
#       (residual): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): GELU(approximate='none')
#         (2): ConvBlock(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (3): ConvBlock(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#         )
#         (4): SqueezeExciteBlock(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (2): GELU(approximate='none')
#             (3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (5): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (3): BlockStack(
#     (0): TransformerBlock(
#       (0): Residual(
#         (shortcut): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (2): SelfAttention2d(
#             (to_keys): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#             (to_queries): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#             (to_values): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#             (unifyheads): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#       (1): Residual(
#         (shortcut): Identity()
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): FeedForward(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (1): GELU(approximate='none')
#             (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#             (3): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#     )
#     (1): TransformerBlock(
#       (0): Residual(
#         (shortcut): Identity()
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): Identity()
#           (2): SelfAttention2d(
#             (to_keys): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (to_queries): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (to_values): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (unifyheads): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#       (1): Residual(
#         (shortcut): Identity()
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): FeedForward(
#             (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#             (1): GELU(approximate='none')
#             (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#             (3): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (4): BlockStack(
#     (0): TransformerBlock(
#       (0): Residual(
#         (shortcut): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (2): SelfAttention2d(
#             (to_keys): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             (to_queries): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             (to_values): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#             (unifyheads): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#       (1): Residual(
#         (shortcut): Identity()
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): FeedForward(
#             (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (1): GELU(approximate='none')
#             (2): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#             (3): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#     )
#     (1): TransformerBlock(
#       (0): Residual(
#         (shortcut): Identity()
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): Identity()
#           (2): SelfAttention2d(
#             (to_keys): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (to_queries): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (to_values): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (unifyheads): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#       (1): Residual(
#         (shortcut): Identity()
#         (residual): Sequential(
#           (0): LayerNormChannels(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           )
#           (1): FeedForward(
#             (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#             (1): GELU(approximate='none')
#             (2): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#             (3): Dropout(p=0.3, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (5): Head(
#     (0): LayerNormChannels(
#       (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): AdaptiveAvgPool2d(output_size=1)
#     (2): Flatten(start_dim=1, end_dim=-1)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=512, out_features=36, bias=True)
#   )
# )

# %% [markdown]
# ### Training

# %%
class EarlyStopping():
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        
    def __call__(self, val_loss):
        print("val_loss, best_loss", val_loss, self.best_loss)
        if self.best_loss == None:
            self.best_loss = val_loss
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            # reset counter if validation loss improves
            self.counter = 0
        elif self.best_loss - val_loss < self.min_delta:
            self.counter += 1
            print(f"INFO: Early stopping counter {self.counter} of {self.patience}")
            if self.counter >= self.patience:
                print('INFO: Early stopping')
                self.early_stop = True

# %%
def train_model():
    criterion = nn.CrossEntropyLoss()
    optimizer = get_optimizer(model, learning_rate=1e-6, weight_decay=WEIGHT_DECAY)
    lr_scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LEARNING_RATE,
                                                 steps_per_epoch=len(train_loader), epochs=EPOCHS)

    num_epochs = EPOCHS
    device = DEVICE
    early_stopping = EarlyStopping(patience=45, min_delta=0)

    for epoch in range(num_epochs):
        result_dict['epochs'].append(epoch)
        model.train()
        correct = 0
        total = 0
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward and optimize
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
        
        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item()}")
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        result_dict['train_data_loss'].append(loss.item())
        result_dict['train_data_acc'].append(correct/total)

        # Validation
        if (epoch + 1) % 1 == 0:
            model.eval()
            with torch.no_grad():
                correct = 0
                total = 0
                for inputs, labels in val_loader:
                    inputs = inputs.to(device)
                    labels = labels.to(device)
                    outputs = model(inputs)
                    
                    loss = criterion(outputs, labels)
                    
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

                print(f"Validation Accuracy: {correct/total}")
                result_dict['val_data_loss'].append(loss.item())
                result_dict['val_data_acc'].append(correct/total)

        if (epoch + 1) % 50 == 0:
            print_res()
        
        # early stopping
        early_stopping(loss.item())
        if early_stopping.early_stop:
            print("We are at epoch:", epoch)
            torch.save(model.state_dict(), MODEL_PATH)
            print("model has been saved at path:", MODEL_PATH)
            break

# %%
train_model()
# Out:
# Epoch [1/1100], Loss: 4.035736083984375
# Validation Accuracy: 0.027777777777777776
# val_loss, best_loss 3.9746599197387695 None
# Epoch [2/1100], Loss: 3.984304666519165
# Validation Accuracy: 0.03333333333333333
# val_loss, best_loss 3.4015228748321533 3.9746599197387695
# Epoch [3/1100], Loss: 3.675689220428467
# Validation Accuracy: 0.03333333333333333
# val_loss, best_loss 3.6278867721557617 3.4015228748321533
# INFO: Early stopping counter 1 of 45
# Epoch [4/1100], Loss: 3.7404255867004395
# Validation Accuracy: 0.03333333333333333
# val_loss, best_loss 3.4477946758270264 3.4015228748321533
# INFO: Early stopping counter 2 of 45
# Epoch [5/1100], Loss: 3.6687889099121094
# Validation Accuracy: 0.027777777777777776
# val_loss, best_loss 3.5646557807922363 3.4015228748321533
# INFO: Early stopping counter 3 of 45
# Epoch [6/1100], Loss: 3.8406951427459717
# Validation Accuracy: 0.03888888888888889
# val_loss, best_loss 3.4150962829589844 3.4015228748321533
# INFO: Early stopping counter 4 of 45
# Epoch [7/1100], Loss: 3.7437970638275146
# Validation Accuracy: 0.027777777777777776
# val_loss, best_loss 3.5009822845458984 3.4015228748321533
# INFO: Early stopping counter 5 of 45
# Epoch [8/1100], Loss: 3.8370492458343506
# Validation Accuracy: 0.03888888888888889
# val_loss, best_loss 3.7267839908599854 3.4015228748321533
# INFO: Early stopping counter 6 of 45
# Epoch [9/1100], Loss: 3.7501232624053955
# Validation Accuracy: 0.03888888888888889
# val_loss, best_loss 3.6565122604370117 3.4015228748321533
# INFO: Early stopping counter 7 of 45
# Epoch [10/1100], Loss: 3.5786807537078857
# Validation Accuracy: 0.03333333333333333
# val_loss, best_loss 3.596151113510132 3.4015228748321533
# INFO: Early stopping counter 8 of 45
# Epoch [11/1100], Loss: 3.8667476177215576
# Validation Accuracy: 0.03888888888888889
# val_loss, best_loss 3.6081924438476562 3.4015228748321533
# INFO: Early stopping counter 9 of 45
# Epoch [12/1100], Loss: 3.5854666233062744
# Validation Accuracy: 0.044444444444444446
# val_loss, best_loss 3.482631206512451 3.4015228748321533
# INFO: Early stopping counter 10 of 45
# Epoch [13/1100], Loss: 3.860607385635376
# Validation Accuracy: 0.05555555555555555
# val_loss, best_loss 3.34041166305542 3.4015228748321533
# Epoch [14/1100], Loss: 3.852421283721924
# Validation Accuracy: 0.03333333333333333
# val_loss, best_loss 3.6907312870025635 3.34041166305542
# INFO: Early stopping counter 1 of 45
# Epoch [15/1100], Loss: 3.5304582118988037
# Validation Accuracy: 0.05
# val_loss, best_loss 3.2518961429595947 3.34041166305542
# Epoch [16/1100], Loss: 3.5541839599609375
# Validation Accuracy: 0.044444444444444446
# val_loss, best_loss 3.5684118270874023 3.2518961429595947
# INFO: Early stopping counter 1 of 45
# Epoch [17/1100], Loss: 3.392782211303711
# Validation Accuracy: 0.05
# val_loss, best_loss 3.632430076599121 3.2518961429595947
# INFO: Early stopping counter 2 of 45
# Epoch [18/1100], Loss: 3.4040260314941406
# Validation Accuracy: 0.044444444444444446
# val_loss, best_loss 3.751303195953369 3.2518961429595947
# INFO: Early stopping counter 3 of 45
# Epoch [19/1100], Loss: 3.7762644290924072
# Validation Accuracy: 0.05555555555555555
# val_loss, best_loss 3.4277713298797607 3.2518961429595947
# INFO: Early stopping counter 4 of 45
# Epoch [20/1100], Loss: 3.6137256622314453
# Validation Accuracy: 0.05555555555555555
# val_loss, best_loss 3.5825202465057373 3.2518961429595947
# INFO: Early stopping counter 5 of 45
# Epoch [21/1100], Loss: 3.5794503688812256
# Validation Accuracy: 0.05
# val_loss, best_loss 3.5161819458007812 3.2518961429595947
# INFO: Early stopping counter 6 of 45
# Epoch [22/1100], Loss: 3.2164595127105713
# Validation Accuracy: 0.05555555555555555
# val_loss, best_loss 3.4832897186279297 3.2518961429595947
# INFO: Early stopping counter 7 of 45
# Epoch [23/1100], Loss: 3.596194267272949
# Validation Accuracy: 0.05
# val_loss, best_loss 3.594306468963623 3.2518961429595947
# INFO: Early stopping counter 8 of 45
# Epoch [24/1100], Loss: 3.3713419437408447
# Validation Accuracy: 0.07222222222222222
# val_loss, best_loss 3.389554262161255 3.2518961429595947
# INFO: Early stopping counter 9 of 45
# Epoch [25/1100], Loss: 3.331667900085449
# Validation Accuracy: 0.06666666666666667
# val_loss, best_loss 3.159512519836426 3.2518961429595947
# Epoch [26/1100], Loss: 3.5303165912628174
# Validation Accuracy: 0.05555555555555555
# val_loss, best_loss 3.6824679374694824 3.159512519836426
# INFO: Early stopping counter 1 of 45
# Epoch [27/1100], Loss: 3.3927602767944336
# Validation Accuracy: 0.05
# val_loss, best_loss 3.7243518829345703 3.159512519836426
# INFO: Early stopping counter 2 of 45
# Epoch [28/1100], Loss: 3.456494092941284
# Validation Accuracy: 0.07222222222222222
# val_loss, best_loss 3.4296762943267822 3.159512519836426
# INFO: Early stopping counter 3 of 45
# Epoch [29/1100], Loss: 3.420238494873047
# Validation Accuracy: 0.06111111111111111
# val_loss, best_loss 3.628627300262451 3.159512519836426
# INFO: Early stopping counter 4 of 45
# Epoch [30/1100], Loss: 3.7173118591308594
# Validation Accuracy: 0.06111111111111111
# val_loss, best_loss 3.223066806793213 3.159512519836426
# INFO: Early stopping counter 5 of 45
# Epoch [31/1100], Loss: 3.1926114559173584
# Validation Accuracy: 0.07222222222222222
# val_loss, best_loss 3.0550220012664795 3.159512519836426
# Epoch [32/1100], Loss: 3.022712230682373
# Validation Accuracy: 0.06111111111111111
# val_loss, best_loss 3.1561198234558105 3.0550220012664795
# INFO: Early stopping counter 1 of 45
# Epoch [33/1100], Loss: 3.082069158554077
# Validation Accuracy: 0.07777777777777778
# val_loss, best_loss 3.213151454925537 3.0550220012664795
# INFO: Early stopping counter 2 of 45
# Epoch [34/1100], Loss: 3.1633381843566895
# Validation Accuracy: 0.1
# val_loss, best_loss 2.8745224475860596 3.0550220012664795
# Epoch [35/1100], Loss: 3.1729543209075928
# Validation Accuracy: 0.10555555555555556
# val_loss, best_loss 3.353222608566284 2.8745224475860596
# INFO: Early stopping counter 1 of 45
# Epoch [36/1100], Loss: 3.3470919132232666
# Validation Accuracy: 0.09444444444444444
# val_loss, best_loss 3.034539222717285 2.8745224475860596
# INFO: Early stopping counter 2 of 45
# Epoch [37/1100], Loss: 2.9713823795318604
# Validation Accuracy: 0.10555555555555556
# val_loss, best_loss 3.5196573734283447 2.8745224475860596
# INFO: Early stopping counter 3 of 45
# Epoch [38/1100], Loss: 3.102442979812622
# Validation Accuracy: 0.11666666666666667
# val_loss, best_loss 3.363386392593384 2.8745224475860596
# INFO: Early stopping counter 4 of 45
# Epoch [39/1100], Loss: 2.893568992614746
# Validation Accuracy: 0.14444444444444443
# val_loss, best_loss 2.8624868392944336 2.8745224475860596
# Epoch [40/1100], Loss: 3.116109848022461
# Validation Accuracy: 0.12222222222222222
# val_loss, best_loss 2.3050076961517334 2.8624868392944336
# Epoch [41/1100], Loss: 3.255357503890991
# Validation Accuracy: 0.10555555555555556
# val_loss, best_loss 3.2900185585021973 2.3050076961517334
# INFO: Early stopping counter 1 of 45
# Epoch [42/1100], Loss: 2.7485625743865967
# Validation Accuracy: 0.15
# val_loss, best_loss 3.341987133026123 2.3050076961517334
# INFO: Early stopping counter 2 of 45
# Epoch [43/1100], Loss: 2.8685848712921143
# Validation Accuracy: 0.1388888888888889
# val_loss, best_loss 2.9217734336853027 2.3050076961517334
# INFO: Early stopping counter 3 of 45
# Epoch [44/1100], Loss: 2.91648530960083
# Validation Accuracy: 0.15
# val_loss, best_loss 3.3024985790252686 2.3050076961517334
# INFO: Early stopping counter 4 of 45
# Epoch [45/1100], Loss: 2.7528743743896484
# Validation Accuracy: 0.2
# val_loss, best_loss 3.230557441711426 2.3050076961517334
# INFO: Early stopping counter 5 of 45
# Epoch [46/1100], Loss: 2.812976837158203
# Validation Accuracy: 0.15
# val_loss, best_loss 2.601469039916992 2.3050076961517334
# INFO: Early stopping counter 6 of 45
# Epoch [47/1100], Loss: 2.5038890838623047
# Validation Accuracy: 0.15555555555555556
# val_loss, best_loss 2.881606101989746 2.3050076961517334
# INFO: Early stopping counter 7 of 45
# Epoch [48/1100], Loss: 2.9348902702331543
# Validation Accuracy: 0.19444444444444445
# val_loss, best_loss 3.0882761478424072 2.3050076961517334
# INFO: Early stopping counter 8 of 45
# Epoch [49/1100], Loss: 2.791166305541992
# Validation Accuracy: 0.15555555555555556
# val_loss, best_loss 2.680537700653076 2.3050076961517334
# INFO: Early stopping counter 9 of 45
# Epoch [50/1100], Loss: 2.684267520904541
# Validation Accuracy: 0.17222222222222222
# val_loss, best_loss 2.5905075073242188 2.3050076961517334
# INFO: Early stopping counter 10 of 45
# Epoch [51/1100], Loss: 2.584733724594116
# Validation Accuracy: 0.16666666666666666
# val_loss, best_loss 2.945284843444824 2.3050076961517334
# INFO: Early stopping counter 11 of 45
# Epoch [52/1100], Loss: 2.657719373703003
# Validation Accuracy: 0.17222222222222222
# val_loss, best_loss 1.672530174255371 2.3050076961517334
# Epoch [53/1100], Loss: 2.481750726699829
# Validation Accuracy: 0.16666666666666666
# val_loss, best_loss 2.071683168411255 1.672530174255371
# INFO: Early stopping counter 1 of 45
# Epoch [54/1100], Loss: 2.997403860092163
# Validation Accuracy: 0.2222222222222222
# val_loss, best_loss 1.9706783294677734 1.672530174255371
# INFO: Early stopping counter 2 of 45
# Epoch [55/1100], Loss: 2.498037338256836
# Validation Accuracy: 0.17777777777777778
# val_loss, best_loss 2.914466619491577 1.672530174255371
# INFO: Early stopping counter 3 of 45
# Epoch [56/1100], Loss: 2.3450615406036377
# Validation Accuracy: 0.22777777777777777
# val_loss, best_loss 2.5389811992645264 1.672530174255371
# INFO: Early stopping counter 4 of 45
# Epoch [57/1100], Loss: 2.4970462322235107
# Validation Accuracy: 0.2388888888888889
# val_loss, best_loss 2.837057590484619 1.672530174255371
# INFO: Early stopping counter 5 of 45
# Epoch [58/1100], Loss: 2.606745481491089
# Validation Accuracy: 0.22777777777777777
# val_loss, best_loss 2.7752127647399902 1.672530174255371
# INFO: Early stopping counter 6 of 45
# Epoch [59/1100], Loss: 2.5126893520355225
# Validation Accuracy: 0.26666666666666666
# val_loss, best_loss 2.8918843269348145 1.672530174255371
# INFO: Early stopping counter 7 of 45
# Epoch [60/1100], Loss: 2.3040146827697754
# Validation Accuracy: 0.2111111111111111
# val_loss, best_loss 1.8910458087921143 1.672530174255371
# INFO: Early stopping counter 8 of 45
# Epoch [61/1100], Loss: 2.162945032119751
# Validation Accuracy: 0.2777777777777778
# val_loss, best_loss 3.179140567779541 1.672530174255371
# INFO: Early stopping counter 9 of 45
# Epoch [62/1100], Loss: 2.256110668182373
# Validation Accuracy: 0.18333333333333332
# val_loss, best_loss 2.3361899852752686 1.672530174255371
# INFO: Early stopping counter 10 of 45
# Epoch [63/1100], Loss: 1.875428557395935
# Validation Accuracy: 0.2722222222222222
# val_loss, best_loss 1.5246872901916504 1.672530174255371
# Epoch [64/1100], Loss: 2.4011929035186768
# Validation Accuracy: 0.2833333333333333
# val_loss, best_loss 1.6214338541030884 1.5246872901916504
# INFO: Early stopping counter 1 of 45
# Epoch [65/1100], Loss: 2.585002899169922
# Validation Accuracy: 0.25555555555555554
# val_loss, best_loss 1.2863712310791016 1.5246872901916504
# Epoch [66/1100], Loss: 2.004875421524048
# Validation Accuracy: 0.25
# val_loss, best_loss 3.10555362701416 1.2863712310791016
# INFO: Early stopping counter 1 of 45
# Epoch [67/1100], Loss: 2.156517505645752
# Validation Accuracy: 0.26666666666666666
# val_loss, best_loss 2.2115533351898193 1.2863712310791016
# INFO: Early stopping counter 2 of 45
# Epoch [68/1100], Loss: 2.0820608139038086
# Validation Accuracy: 0.21666666666666667
# val_loss, best_loss 1.2319822311401367 1.2863712310791016
# Epoch [69/1100], Loss: 2.4515340328216553
# Validation Accuracy: 0.3333333333333333
# val_loss, best_loss 2.638028860092163 1.2319822311401367
# INFO: Early stopping counter 1 of 45
# Epoch [70/1100], Loss: 2.028597831726074
# Validation Accuracy: 0.3055555555555556
# val_loss, best_loss 2.2698349952697754 1.2319822311401367
# INFO: Early stopping counter 2 of 45
# Epoch [71/1100], Loss: 1.9238991737365723
# Validation Accuracy: 0.3888888888888889
# val_loss, best_loss 1.9608582258224487 1.2319822311401367
# INFO: Early stopping counter 3 of 45
# Epoch [72/1100], Loss: 2.522601842880249
# Validation Accuracy: 0.3055555555555556
# val_loss, best_loss 3.0878500938415527 1.2319822311401367
# INFO: Early stopping counter 4 of 45
# Epoch [73/1100], Loss: 1.8221014738082886
# Validation Accuracy: 0.2833333333333333
# val_loss, best_loss 2.1637749671936035 1.2319822311401367
# INFO: Early stopping counter 5 of 45
# Epoch [74/1100], Loss: 1.8061950206756592
# Validation Accuracy: 0.4
# val_loss, best_loss 2.3220937252044678 1.2319822311401367
# INFO: Early stopping counter 6 of 45
# Epoch [75/1100], Loss: 1.9402296543121338
# Validation Accuracy: 0.4
# val_loss, best_loss 1.5242375135421753 1.2319822311401367
# INFO: Early stopping counter 7 of 45
# Epoch [76/1100], Loss: 1.946016788482666
# Validation Accuracy: 0.3611111111111111
# val_loss, best_loss 2.52219820022583 1.2319822311401367
# INFO: Early stopping counter 8 of 45
# Epoch [77/1100], Loss: 1.8555189371109009
# Validation Accuracy: 0.4222222222222222
# val_loss, best_loss 2.282334089279175 1.2319822311401367
# INFO: Early stopping counter 9 of 45
# Epoch [78/1100], Loss: 2.042574644088745
# Validation Accuracy: 0.40555555555555556
# val_loss, best_loss 2.1399075984954834 1.2319822311401367
# INFO: Early stopping counter 10 of 45
# Epoch [79/1100], Loss: 1.5744708776474
# Validation Accuracy: 0.4166666666666667
# val_loss, best_loss 2.0550222396850586 1.2319822311401367
# INFO: Early stopping counter 11 of 45
# Epoch [80/1100], Loss: 1.82395601272583
# Validation Accuracy: 0.42777777777777776
# val_loss, best_loss 1.429135799407959 1.2319822311401367
# INFO: Early stopping counter 12 of 45
# Epoch [81/1100], Loss: 1.6754097938537598
# Validation Accuracy: 0.4111111111111111
# val_loss, best_loss 1.242279291152954 1.2319822311401367
# INFO: Early stopping counter 13 of 45
# Epoch [82/1100], Loss: 1.8042917251586914
# Validation Accuracy: 0.4388888888888889
# val_loss, best_loss 1.4857139587402344 1.2319822311401367
# INFO: Early stopping counter 14 of 45
# Epoch [83/1100], Loss: 1.6889019012451172
# Validation Accuracy: 0.46111111111111114
# val_loss, best_loss 2.2723000049591064 1.2319822311401367
# INFO: Early stopping counter 15 of 45
# Epoch [84/1100], Loss: 1.7589044570922852
# Validation Accuracy: 0.5611111111111111
# val_loss, best_loss 1.3131905794143677 1.2319822311401367
# INFO: Early stopping counter 16 of 45
# Epoch [85/1100], Loss: 2.1140785217285156
# Validation Accuracy: 0.4722222222222222
# val_loss, best_loss 1.6253716945648193 1.2319822311401367
# INFO: Early stopping counter 17 of 45
# Epoch [86/1100], Loss: 1.789241909980774
# Validation Accuracy: 0.4722222222222222
# val_loss, best_loss 0.9078869819641113 1.2319822311401367
# Epoch [87/1100], Loss: 1.5089415311813354
# Validation Accuracy: 0.5166666666666667
# val_loss, best_loss 1.6303551197052002 0.9078869819641113
# INFO: Early stopping counter 1 of 45
# Epoch [88/1100], Loss: 1.7308599948883057
# Validation Accuracy: 0.48333333333333334
# val_loss, best_loss 1.8071479797363281 0.9078869819641113
# INFO: Early stopping counter 2 of 45
# Epoch [89/1100], Loss: 2.4598140716552734
# Validation Accuracy: 0.55
# val_loss, best_loss 1.8551182746887207 0.9078869819641113
# INFO: Early stopping counter 3 of 45
# Epoch [90/1100], Loss: 1.5744991302490234
# Validation Accuracy: 0.5444444444444444
# val_loss, best_loss 1.5680893659591675 0.9078869819641113
# INFO: Early stopping counter 4 of 45
# Epoch [91/1100], Loss: 1.4612903594970703
# Validation Accuracy: 0.5388888888888889
# val_loss, best_loss 1.0003751516342163 0.9078869819641113
# INFO: Early stopping counter 5 of 45
# Epoch [92/1100], Loss: 1.4910786151885986
# Validation Accuracy: 0.5055555555555555
# val_loss, best_loss 1.13193941116333 0.9078869819641113
# INFO: Early stopping counter 6 of 45
# Epoch [93/1100], Loss: 1.2150804996490479
# Validation Accuracy: 0.4777777777777778
# val_loss, best_loss 1.7839388847351074 0.9078869819641113
# INFO: Early stopping counter 7 of 45
# Epoch [94/1100], Loss: 0.951893150806427
# Validation Accuracy: 0.5722222222222222
# val_loss, best_loss 0.40945929288864136 0.9078869819641113
# Epoch [95/1100], Loss: 1.749884843826294
# Validation Accuracy: 0.5
# val_loss, best_loss 1.1085313558578491 0.40945929288864136
# INFO: Early stopping counter 1 of 45
# Epoch [96/1100], Loss: 1.3714189529418945
# Validation Accuracy: 0.5444444444444444
# val_loss, best_loss 0.8509870171546936 0.40945929288864136
# INFO: Early stopping counter 2 of 45
# Epoch [97/1100], Loss: 2.088101387023926
# Validation Accuracy: 0.5
# val_loss, best_loss 0.7935467958450317 0.40945929288864136
# INFO: Early stopping counter 3 of 45
# Epoch [98/1100], Loss: 1.6165069341659546
# Validation Accuracy: 0.5611111111111111
# val_loss, best_loss 1.4914847612380981 0.40945929288864136
# INFO: Early stopping counter 4 of 45
# Epoch [99/1100], Loss: 1.2776930332183838
# Validation Accuracy: 0.5444444444444444
# val_loss, best_loss 0.8798031806945801 0.40945929288864136
# INFO: Early stopping counter 5 of 45
# Epoch [100/1100], Loss: 1.5415204763412476
# Validation Accuracy: 0.5666666666666667
# val_loss, best_loss 1.30068838596344 0.40945929288864136
# INFO: Early stopping counter 6 of 45
# Epoch [101/1100], Loss: 1.405248999595642
# Validation Accuracy: 0.5333333333333333
# val_loss, best_loss 3.2459397315979004 0.40945929288864136
# INFO: Early stopping counter 7 of 45
# Epoch [102/1100], Loss: 0.8365639448165894
# Validation Accuracy: 0.5555555555555556
# val_loss, best_loss 0.9662202596664429 0.40945929288864136
# INFO: Early stopping counter 8 of 45
# Epoch [103/1100], Loss: 1.6011494398117065
# Validation Accuracy: 0.5777777777777777
# val_loss, best_loss 1.6418774127960205 0.40945929288864136
# INFO: Early stopping counter 9 of 45
# Epoch [104/1100], Loss: 0.8797351717948914
# Validation Accuracy: 0.6722222222222223
# val_loss, best_loss 0.8907400369644165 0.40945929288864136
# INFO: Early stopping counter 10 of 45
# Epoch [105/1100], Loss: 1.3371844291687012
# Validation Accuracy: 0.6333333333333333
# val_loss, best_loss 1.220277190208435 0.40945929288864136
# INFO: Early stopping counter 11 of 45
# Epoch [106/1100], Loss: 1.4517050981521606
# Validation Accuracy: 0.6666666666666666
# val_loss, best_loss 0.7195352911949158 0.40945929288864136
# INFO: Early stopping counter 12 of 45
# Epoch [107/1100], Loss: 1.3583978414535522
# Validation Accuracy: 0.6222222222222222
# val_loss, best_loss 2.6955931186676025 0.40945929288864136
# INFO: Early stopping counter 13 of 45
# Epoch [108/1100], Loss: 0.8921221494674683
# Validation Accuracy: 0.5777777777777777
# val_loss, best_loss 1.7445367574691772 0.40945929288864136
# INFO: Early stopping counter 14 of 45
# Epoch [109/1100], Loss: 1.21865713596344
# Validation Accuracy: 0.6166666666666667
# val_loss, best_loss 0.8687261343002319 0.40945929288864136
# INFO: Early stopping counter 15 of 45
# Epoch [110/1100], Loss: 0.8163220882415771
# Validation Accuracy: 0.6333333333333333
# val_loss, best_loss 1.7551708221435547 0.40945929288864136
# INFO: Early stopping counter 16 of 45
# Epoch [111/1100], Loss: 0.9130427241325378
# Validation Accuracy: 0.5722222222222222
# val_loss, best_loss 0.5493823289871216 0.40945929288864136
# INFO: Early stopping counter 17 of 45
# Epoch [112/1100], Loss: 1.1937260627746582
# Validation Accuracy: 0.6111111111111112
# val_loss, best_loss 0.6324037313461304 0.40945929288864136
# INFO: Early stopping counter 18 of 45
# Epoch [113/1100], Loss: 0.8213362097740173
# Validation Accuracy: 0.6944444444444444
# val_loss, best_loss 0.8299601674079895 0.40945929288864136
# INFO: Early stopping counter 19 of 45
# Epoch [114/1100], Loss: 0.6775998473167419
# Validation Accuracy: 0.6555555555555556
# val_loss, best_loss 0.4919193387031555 0.40945929288864136
# INFO: Early stopping counter 20 of 45
# Epoch [115/1100], Loss: 0.6723813414573669
# Validation Accuracy: 0.6333333333333333
# val_loss, best_loss 0.9011345505714417 0.40945929288864136
# INFO: Early stopping counter 21 of 45
# Epoch [116/1100], Loss: 1.3220493793487549
# Validation Accuracy: 0.6777777777777778
# val_loss, best_loss 1.1585795879364014 0.40945929288864136
# INFO: Early stopping counter 22 of 45
# Epoch [117/1100], Loss: 0.8902665972709656
# Validation Accuracy: 0.6777777777777778
# val_loss, best_loss 0.691903829574585 0.40945929288864136
# INFO: Early stopping counter 23 of 45
# Epoch [118/1100], Loss: 0.626762866973877
# Validation Accuracy: 0.6944444444444444
# val_loss, best_loss 1.7585786581039429 0.40945929288864136
# INFO: Early stopping counter 24 of 45
# Epoch [119/1100], Loss: 0.48898744583129883
# Validation Accuracy: 0.6555555555555556
# val_loss, best_loss 0.9173619747161865 0.40945929288864136
# INFO: Early stopping counter 25 of 45
# Epoch [120/1100], Loss: 0.9466605186462402
# Validation Accuracy: 0.6666666666666666
# val_loss, best_loss 1.6263272762298584 0.40945929288864136
# INFO: Early stopping counter 26 of 45
# Epoch [121/1100], Loss: 0.7103140354156494
# Validation Accuracy: 0.6611111111111111
# val_loss, best_loss 1.3158564567565918 0.40945929288864136
# INFO: Early stopping counter 27 of 45
# Epoch [122/1100], Loss: 0.9113785028457642
# Validation Accuracy: 0.7111111111111111
# val_loss, best_loss 1.660402774810791 0.40945929288864136
# INFO: Early stopping counter 28 of 45
# Epoch [123/1100], Loss: 1.2558817863464355
# Validation Accuracy: 0.5777777777777777
# val_loss, best_loss 0.7423337697982788 0.40945929288864136
# INFO: Early stopping counter 29 of 45
# Epoch [124/1100], Loss: 0.7772973775863647
# Validation Accuracy: 0.6888888888888889
# val_loss, best_loss 0.5106892585754395 0.40945929288864136
# INFO: Early stopping counter 30 of 45
# Epoch [125/1100], Loss: 0.3580709993839264
# Validation Accuracy: 0.75
# val_loss, best_loss 0.49424171447753906 0.40945929288864136
# INFO: Early stopping counter 31 of 45
# Epoch [126/1100], Loss: 0.6940680742263794
# Validation Accuracy: 0.6944444444444444
# val_loss, best_loss 0.5213170647621155 0.40945929288864136
# INFO: Early stopping counter 32 of 45
# Epoch [127/1100], Loss: 0.9764794707298279
# Validation Accuracy: 0.7333333333333333
# val_loss, best_loss 0.26392120122909546 0.40945929288864136
# Epoch [128/1100], Loss: 0.4781428575515747
# Validation Accuracy: 0.6888888888888889
# val_loss, best_loss 0.05880065634846687 0.26392120122909546
# Epoch [129/1100], Loss: 0.612417995929718
# Validation Accuracy: 0.7555555555555555
# val_loss, best_loss 2.2893025875091553 0.05880065634846687
# INFO: Early stopping counter 1 of 45
# Epoch [130/1100], Loss: 0.4553055763244629
# Validation Accuracy: 0.7555555555555555
# val_loss, best_loss 0.6094456315040588 0.05880065634846687
# INFO: Early stopping counter 2 of 45
# Epoch [131/1100], Loss: 0.34055107831954956
# Validation Accuracy: 0.6944444444444444
# val_loss, best_loss 1.3424283266067505 0.05880065634846687
# INFO: Early stopping counter 3 of 45
# Epoch [132/1100], Loss: 0.7368740439414978
# Validation Accuracy: 0.7555555555555555
# val_loss, best_loss 0.10532373189926147 0.05880065634846687
# INFO: Early stopping counter 4 of 45
# Epoch [133/1100], Loss: 0.5543034076690674
# Validation Accuracy: 0.6833333333333333
# val_loss, best_loss 0.7307738065719604 0.05880065634846687
# INFO: Early stopping counter 5 of 45
# Epoch [134/1100], Loss: 0.3364737629890442
# Validation Accuracy: 0.7388888888888889
# val_loss, best_loss 2.3057494163513184 0.05880065634846687
# INFO: Early stopping counter 6 of 45
# Epoch [135/1100], Loss: 1.1493669748306274
# Validation Accuracy: 0.7277777777777777
# val_loss, best_loss 1.1763584613800049 0.05880065634846687
# INFO: Early stopping counter 7 of 45
# Epoch [136/1100], Loss: 0.23776043951511383
# Validation Accuracy: 0.7333333333333333
# val_loss, best_loss 0.19301915168762207 0.05880065634846687
# INFO: Early stopping counter 8 of 45
# Epoch [137/1100], Loss: 0.13662056624889374
# Validation Accuracy: 0.7388888888888889
# val_loss, best_loss 1.071770429611206 0.05880065634846687
# INFO: Early stopping counter 9 of 45
# Epoch [138/1100], Loss: 0.6214497685432434
# Validation Accuracy: 0.7277777777777777
# val_loss, best_loss 0.5453802943229675 0.05880065634846687
# INFO: Early stopping counter 10 of 45
# Epoch [139/1100], Loss: 0.28242069482803345
# Validation Accuracy: 0.7722222222222223
# val_loss, best_loss 0.8867730498313904 0.05880065634846687
# INFO: Early stopping counter 11 of 45
# Epoch [140/1100], Loss: 0.49529528617858887
# Validation Accuracy: 0.7555555555555555
# val_loss, best_loss 1.2342756986618042 0.05880065634846687
# INFO: Early stopping counter 12 of 45
# Epoch [141/1100], Loss: 1.1611652374267578
# Validation Accuracy: 0.7611111111111111
# val_loss, best_loss 0.7592940926551819 0.05880065634846687
# INFO: Early stopping counter 13 of 45
# Epoch [142/1100], Loss: 0.4379567503929138
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 0.7773054242134094 0.05880065634846687
# INFO: Early stopping counter 14 of 45
# Epoch [143/1100], Loss: 1.009307622909546
# Validation Accuracy: 0.7222222222222222
# val_loss, best_loss 2.026543140411377 0.05880065634846687
# INFO: Early stopping counter 15 of 45
# Epoch [144/1100], Loss: 0.6747868061065674
# Validation Accuracy: 0.7055555555555556
# val_loss, best_loss 0.9870315790176392 0.05880065634846687
# INFO: Early stopping counter 16 of 45
# Epoch [145/1100], Loss: 0.661322295665741
# Validation Accuracy: 0.7333333333333333
# val_loss, best_loss 0.03567884862422943 0.05880065634846687
# Epoch [146/1100], Loss: 0.5426604747772217
# Validation Accuracy: 0.7111111111111111
# val_loss, best_loss 0.9106889963150024 0.03567884862422943
# INFO: Early stopping counter 1 of 45
# Epoch [147/1100], Loss: 0.8145624995231628
# Validation Accuracy: 0.7222222222222222
# val_loss, best_loss 1.1443980932235718 0.03567884862422943
# INFO: Early stopping counter 2 of 45
# Epoch [148/1100], Loss: 0.26254576444625854
# Validation Accuracy: 0.7611111111111111
# val_loss, best_loss 0.6190893650054932 0.03567884862422943
# INFO: Early stopping counter 3 of 45
# Epoch [149/1100], Loss: 0.16988439857959747
# Validation Accuracy: 0.8444444444444444
# val_loss, best_loss 0.411510705947876 0.03567884862422943
# INFO: Early stopping counter 4 of 45
# Epoch [150/1100], Loss: 0.4488774240016937
# Validation Accuracy: 0.7777777777777778
# val_loss, best_loss 0.19233311712741852 0.03567884862422943
# INFO: Early stopping counter 5 of 45
# Epoch [151/1100], Loss: 0.7053396105766296
# Validation Accuracy: 0.7833333333333333
# val_loss, best_loss 0.48144739866256714 0.03567884862422943
# INFO: Early stopping counter 6 of 45
# Epoch [152/1100], Loss: 0.7285409569740295
# Validation Accuracy: 0.7944444444444444
# val_loss, best_loss 0.10751824826002121 0.03567884862422943
# INFO: Early stopping counter 7 of 45
# Epoch [153/1100], Loss: 0.3463124930858612
# Validation Accuracy: 0.7111111111111111
# val_loss, best_loss 1.0887386798858643 0.03567884862422943
# INFO: Early stopping counter 8 of 45
# Epoch [154/1100], Loss: 0.33177080750465393
# Validation Accuracy: 0.7722222222222223
# val_loss, best_loss 0.2689507305622101 0.03567884862422943
# INFO: Early stopping counter 9 of 45
# Epoch [155/1100], Loss: 0.09055156260728836
# Validation Accuracy: 0.8555555555555555
# val_loss, best_loss 0.6589328050613403 0.03567884862422943
# INFO: Early stopping counter 10 of 45
# Epoch [156/1100], Loss: 0.1815052479505539
# Validation Accuracy: 0.7777777777777778
# val_loss, best_loss 0.1865270584821701 0.03567884862422943
# INFO: Early stopping counter 11 of 45
# Epoch [157/1100], Loss: 0.4844875931739807
# Validation Accuracy: 0.7444444444444445
# val_loss, best_loss 0.1546599566936493 0.03567884862422943
# INFO: Early stopping counter 12 of 45
# Epoch [158/1100], Loss: 0.2811387777328491
# Validation Accuracy: 0.7111111111111111
# val_loss, best_loss 0.00962889101356268 0.03567884862422943
# Epoch [159/1100], Loss: 0.3921787142753601
# Validation Accuracy: 0.7722222222222223
# val_loss, best_loss 0.4446025788784027 0.00962889101356268
# INFO: Early stopping counter 1 of 45
# Epoch [160/1100], Loss: 0.37346768379211426
# Validation Accuracy: 0.7722222222222223
# val_loss, best_loss 0.25689688324928284 0.00962889101356268
# INFO: Early stopping counter 2 of 45
# Epoch [161/1100], Loss: 1.1434804201126099
# Validation Accuracy: 0.7944444444444444
# val_loss, best_loss 0.04914497211575508 0.00962889101356268
# INFO: Early stopping counter 3 of 45
# Epoch [162/1100], Loss: 0.2884647250175476
# Validation Accuracy: 0.75
# val_loss, best_loss 0.30114397406578064 0.00962889101356268
# INFO: Early stopping counter 4 of 45
# Epoch [163/1100], Loss: 0.43649664521217346
# Validation Accuracy: 0.7888888888888889
# val_loss, best_loss 0.01432428415864706 0.00962889101356268
# INFO: Early stopping counter 5 of 45
# Epoch [164/1100], Loss: 0.23843958973884583
# Validation Accuracy: 0.8166666666666667
# val_loss, best_loss 0.2127445638179779 0.00962889101356268
# INFO: Early stopping counter 6 of 45
# Epoch [165/1100], Loss: 0.24215982854366302
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 0.247465118765831 0.00962889101356268
# INFO: Early stopping counter 7 of 45
# Epoch [166/1100], Loss: 0.08061062544584274
# Validation Accuracy: 0.8166666666666667
# val_loss, best_loss 0.011863639578223228 0.00962889101356268
# INFO: Early stopping counter 8 of 45
# Epoch [167/1100], Loss: 0.4303381145000458
# Validation Accuracy: 0.7777777777777778
# val_loss, best_loss 1.0732823610305786 0.00962889101356268
# INFO: Early stopping counter 9 of 45
# Epoch [168/1100], Loss: 0.16114351153373718
# Validation Accuracy: 0.7611111111111111
# val_loss, best_loss 0.9178653955459595 0.00962889101356268
# INFO: Early stopping counter 10 of 45
# Epoch [169/1100], Loss: 0.42491650581359863
# Validation Accuracy: 0.8444444444444444
# val_loss, best_loss 0.5889402627944946 0.00962889101356268
# INFO: Early stopping counter 11 of 45
# Epoch [170/1100], Loss: 0.0973537415266037
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 0.015562774613499641 0.00962889101356268
# INFO: Early stopping counter 12 of 45
# Epoch [171/1100], Loss: 0.2610990107059479
# Validation Accuracy: 0.7722222222222223
# val_loss, best_loss 0.13468913733959198 0.00962889101356268
# INFO: Early stopping counter 13 of 45
# Epoch [172/1100], Loss: 0.5525176525115967
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 0.7362265586853027 0.00962889101356268
# INFO: Early stopping counter 14 of 45
# Epoch [173/1100], Loss: 0.19560663402080536
# Validation Accuracy: 0.8
# val_loss, best_loss 1.2326178550720215 0.00962889101356268
# INFO: Early stopping counter 15 of 45
# Epoch [174/1100], Loss: 0.7900450825691223
# Validation Accuracy: 0.7833333333333333
# val_loss, best_loss 0.2813156843185425 0.00962889101356268
# INFO: Early stopping counter 16 of 45
# Epoch [175/1100], Loss: 0.24198929965496063
# Validation Accuracy: 0.7833333333333333
# val_loss, best_loss 0.564635157585144 0.00962889101356268
# INFO: Early stopping counter 17 of 45
# Epoch [176/1100], Loss: 0.26326802372932434
# Validation Accuracy: 0.8388888888888889
# val_loss, best_loss 0.07329104840755463 0.00962889101356268
# INFO: Early stopping counter 18 of 45
# Epoch [177/1100], Loss: 0.11383108049631119
# Validation Accuracy: 0.8555555555555555
# val_loss, best_loss 0.24170248210430145 0.00962889101356268
# INFO: Early stopping counter 19 of 45
# Epoch [178/1100], Loss: 0.145796000957489
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 0.04710160940885544 0.00962889101356268
# INFO: Early stopping counter 20 of 45
# Epoch [179/1100], Loss: 0.3751316964626312
# Validation Accuracy: 0.7611111111111111
# val_loss, best_loss 0.4770203232765198 0.00962889101356268
# INFO: Early stopping counter 21 of 45
# Epoch [180/1100], Loss: 0.3309405446052551
# Validation Accuracy: 0.7944444444444444
# val_loss, best_loss 0.039391882717609406 0.00962889101356268
# INFO: Early stopping counter 22 of 45
# Epoch [181/1100], Loss: 0.24802736937999725
# Validation Accuracy: 0.8444444444444444
# val_loss, best_loss 0.19212040305137634 0.00962889101356268
# INFO: Early stopping counter 23 of 45
# Epoch [182/1100], Loss: 0.09527739137411118
# Validation Accuracy: 0.8277777777777777
# val_loss, best_loss 0.3917351961135864 0.00962889101356268
# INFO: Early stopping counter 24 of 45
# Epoch [183/1100], Loss: 0.32407310605049133
# Validation Accuracy: 0.8222222222222222
# val_loss, best_loss 0.812876284122467 0.00962889101356268
# INFO: Early stopping counter 25 of 45
# Epoch [184/1100], Loss: 0.4334753453731537
# Validation Accuracy: 0.7666666666666667
# val_loss, best_loss 0.34458062052726746 0.00962889101356268
# INFO: Early stopping counter 26 of 45
# Epoch [185/1100], Loss: 0.15161912143230438
# Validation Accuracy: 0.8611111111111112
# val_loss, best_loss 0.036119554191827774 0.00962889101356268
# INFO: Early stopping counter 27 of 45
# Epoch [186/1100], Loss: 0.2534889876842499
# Validation Accuracy: 0.8
# val_loss, best_loss 1.3308525085449219 0.00962889101356268
# INFO: Early stopping counter 28 of 45
# Epoch [187/1100], Loss: 0.22319196164608002
# Validation Accuracy: 0.8222222222222222
# val_loss, best_loss 0.5834000706672668 0.00962889101356268
# INFO: Early stopping counter 29 of 45
# Epoch [188/1100], Loss: 0.4552075266838074
# Validation Accuracy: 0.8777777777777778
# val_loss, best_loss 0.00949904602020979 0.00962889101356268
# Epoch [189/1100], Loss: 0.43079882860183716
# Validation Accuracy: 0.8
# val_loss, best_loss 0.8577991724014282 0.00949904602020979
# INFO: Early stopping counter 1 of 45
# Epoch [190/1100], Loss: 0.1640562117099762
# Validation Accuracy: 0.7944444444444444
# val_loss, best_loss 0.14105835556983948 0.00949904602020979
# INFO: Early stopping counter 2 of 45
# Epoch [191/1100], Loss: 0.17259590327739716
# Validation Accuracy: 0.8611111111111112
# val_loss, best_loss 0.00010427010420244187 0.00949904602020979
# Epoch [192/1100], Loss: 0.13499996066093445
# Validation Accuracy: 0.8444444444444444
# val_loss, best_loss 0.5661583542823792 0.00010427010420244187
# INFO: Early stopping counter 1 of 45
# Epoch [193/1100], Loss: 0.105850949883461
# Validation Accuracy: 0.8222222222222222
# val_loss, best_loss 0.2428903430700302 0.00010427010420244187
# INFO: Early stopping counter 2 of 45
# Epoch [194/1100], Loss: 0.21615445613861084
# Validation Accuracy: 0.7833333333333333
# val_loss, best_loss 0.43175920844078064 0.00010427010420244187
# INFO: Early stopping counter 3 of 45
# Epoch [195/1100], Loss: 0.21779273450374603
# Validation Accuracy: 0.7666666666666667
# val_loss, best_loss 1.6063066720962524 0.00010427010420244187
# INFO: Early stopping counter 4 of 45
# Epoch [196/1100], Loss: 0.11059277504682541
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 2.199293851852417 0.00010427010420244187
# INFO: Early stopping counter 5 of 45
# Epoch [197/1100], Loss: 0.20737354457378387
# Validation Accuracy: 0.8611111111111112
# val_loss, best_loss 0.24411703646183014 0.00010427010420244187
# INFO: Early stopping counter 6 of 45
# Epoch [198/1100], Loss: 0.5301468968391418
# Validation Accuracy: 0.7888888888888889
# val_loss, best_loss 0.29336586594581604 0.00010427010420244187
# INFO: Early stopping counter 7 of 45
# Epoch [199/1100], Loss: 0.25956839323043823
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 0.19384907186031342 0.00010427010420244187
# INFO: Early stopping counter 8 of 45
# Epoch [200/1100], Loss: 0.16935677826404572
# Validation Accuracy: 0.7777777777777778
# val_loss, best_loss 0.5343801379203796 0.00010427010420244187
# INFO: Early stopping counter 9 of 45
# Epoch [201/1100], Loss: 0.19964170455932617
# Validation Accuracy: 0.8277777777777777
# val_loss, best_loss 0.09292907267808914 0.00010427010420244187
# INFO: Early stopping counter 10 of 45
# Epoch [202/1100], Loss: 0.01754789985716343
# Validation Accuracy: 0.85
# val_loss, best_loss 0.1601581871509552 0.00010427010420244187
# INFO: Early stopping counter 11 of 45
# Epoch [203/1100], Loss: 0.09454154223203659
# Validation Accuracy: 0.8
# val_loss, best_loss 0.38668158650398254 0.00010427010420244187
# INFO: Early stopping counter 12 of 45
# Epoch [204/1100], Loss: 0.12024975568056107
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 2.2887816429138184 0.00010427010420244187
# INFO: Early stopping counter 13 of 45
# Epoch [205/1100], Loss: 0.07085134834051132
# Validation Accuracy: 0.8388888888888889
# val_loss, best_loss 1.3276593685150146 0.00010427010420244187
# INFO: Early stopping counter 14 of 45
# Epoch [206/1100], Loss: 0.25831636786460876
# Validation Accuracy: 0.85
# val_loss, best_loss 0.5736624002456665 0.00010427010420244187
# INFO: Early stopping counter 15 of 45
# Epoch [207/1100], Loss: 0.05644334480166435
# Validation Accuracy: 0.8666666666666667
# val_loss, best_loss 0.7296984791755676 0.00010427010420244187
# INFO: Early stopping counter 16 of 45
# Epoch [208/1100], Loss: 0.015104900114238262
# Validation Accuracy: 0.8333333333333334
# val_loss, best_loss 1.0820456743240356 0.00010427010420244187
# INFO: Early stopping counter 17 of 45
# Epoch [209/1100], Loss: 0.46181583404541016
# Validation Accuracy: 0.8555555555555555
# val_loss, best_loss 0.08578068763017654 0.00010427010420244187
# INFO: Early stopping counter 18 of 45
# Epoch [210/1100], Loss: 0.025656184181571007
# Validation Accuracy: 0.8722222222222222
# val_loss, best_loss 0.1902170181274414 0.00010427010420244187
# INFO: Early stopping counter 19 of 45
# Epoch [211/1100], Loss: 0.2256813645362854
# Validation Accuracy: 0.8055555555555556
# val_loss, best_loss 0.6552019119262695 0.00010427010420244187
# INFO: Early stopping counter 20 of 45
# Epoch [212/1100], Loss: 0.04924953728914261
# Validation Accuracy: 0.8222222222222222
# val_loss, best_loss 0.6910692453384399 0.00010427010420244187
# INFO: Early stopping counter 21 of 45
# Epoch [213/1100], Loss: 0.12250015884637833
# Validation Accuracy: 0.8944444444444445
# val_loss, best_loss 0.16159214079380035 0.00010427010420244187
# INFO: Early stopping counter 22 of 45
# Epoch [214/1100], Loss: 0.3538101315498352
# Validation Accuracy: 0.7944444444444444
# val_loss, best_loss 0.8894559144973755 0.00010427010420244187
# INFO: Early stopping counter 23 of 45
# Epoch [215/1100], Loss: 0.10731665045022964
# Validation Accuracy: 0.8944444444444445
# val_loss, best_loss 0.05990195646882057 0.00010427010420244187
# INFO: Early stopping counter 24 of 45
# Epoch [216/1100], Loss: 0.022324997931718826
# Validation Accuracy: 0.8166666666666667
# val_loss, best_loss 1.052725911140442 0.00010427010420244187
# INFO: Early stopping counter 25 of 45
# Epoch [217/1100], Loss: 0.06166740134358406
# Validation Accuracy: 0.8722222222222222
# val_loss, best_loss 0.08970937132835388 0.00010427010420244187
# INFO: Early stopping counter 26 of 45
# Epoch [218/1100], Loss: 0.22193454205989838
# Validation Accuracy: 0.85
# val_loss, best_loss 1.1671534776687622 0.00010427010420244187
# INFO: Early stopping counter 27 of 45
# Epoch [219/1100], Loss: 0.19154708087444305
# Validation Accuracy: 0.8277777777777777
# val_loss, best_loss 1.9115736484527588 0.00010427010420244187
# INFO: Early stopping counter 28 of 45
# Epoch [220/1100], Loss: 0.1269109547138214
# Validation Accuracy: 0.8888888888888888
# val_loss, best_loss 0.6275163888931274 0.00010427010420244187
# INFO: Early stopping counter 29 of 45
# Epoch [221/1100], Loss: 0.11410491168498993
# Validation Accuracy: 0.8666666666666667
# val_loss, best_loss 0.057282861322164536 0.00010427010420244187
# INFO: Early stopping counter 30 of 45
# Epoch [222/1100], Loss: 0.3008347153663635
# Validation Accuracy: 0.8222222222222222
# val_loss, best_loss 0.057233311235904694 0.00010427010420244187
# INFO: Early stopping counter 31 of 45
# Epoch [223/1100], Loss: 0.034334730356931686
# Validation Accuracy: 0.8111111111111111
# val_loss, best_loss 0.3224664628505707 0.00010427010420244187
# INFO: Early stopping counter 32 of 45
# Epoch [224/1100], Loss: 0.09765502065420151
# Validation Accuracy: 0.8555555555555555
# val_loss, best_loss 0.020833909511566162 0.00010427010420244187
# INFO: Early stopping counter 33 of 45
# Epoch [225/1100], Loss: 0.04450554773211479
# Validation Accuracy: 0.9
# val_loss, best_loss 0.16847708821296692 0.00010427010420244187
# INFO: Early stopping counter 34 of 45
# Epoch [226/1100], Loss: 0.08248232305049896
# Validation Accuracy: 0.7833333333333333
# val_loss, best_loss 0.0015066498890519142 0.00010427010420244187
# INFO: Early stopping counter 35 of 45
# Epoch [227/1100], Loss: 0.07379002869129181
# Validation Accuracy: 0.8666666666666667
# val_loss, best_loss 0.05920363962650299 0.00010427010420244187
# INFO: Early stopping counter 36 of 45
# Epoch [228/1100], Loss: 0.10126479715108871
# Validation Accuracy: 0.8611111111111112
# val_loss, best_loss 0.09469727426767349 0.00010427010420244187
# INFO: Early stopping counter 37 of 45
# Epoch [229/1100], Loss: 0.03804069757461548
# Validation Accuracy: 0.8333333333333334
# val_loss, best_loss 0.0575140006840229 0.00010427010420244187
# INFO: Early stopping counter 38 of 45
# Epoch [230/1100], Loss: 0.16737858951091766
# Validation Accuracy: 0.8944444444444445
# val_loss, best_loss 2.374343156814575 0.00010427010420244187
# INFO: Early stopping counter 39 of 45
# Epoch [231/1100], Loss: 0.07843294739723206
# Validation Accuracy: 0.8388888888888889
# val_loss, best_loss 0.9710478782653809 0.00010427010420244187
# INFO: Early stopping counter 40 of 45
# Epoch [232/1100], Loss: 0.24697953462600708
# Validation Accuracy: 0.85
# val_loss, best_loss 0.9174268841743469 0.00010427010420244187
# INFO: Early stopping counter 41 of 45
# Epoch [233/1100], Loss: 0.01793050207197666
# Validation Accuracy: 0.85
# val_loss, best_loss 0.5592935085296631 0.00010427010420244187
# INFO: Early stopping counter 42 of 45
# Epoch [234/1100], Loss: 0.46750879287719727
# Validation Accuracy: 0.8166666666666667
# val_loss, best_loss 0.2355393022298813 0.00010427010420244187
# INFO: Early stopping counter 43 of 45
# Epoch [235/1100], Loss: 0.21354472637176514
# Validation Accuracy: 0.7777777777777778
# val_loss, best_loss 1.1060179471969604 0.00010427010420244187
# INFO: Early stopping counter 44 of 45
# Epoch [236/1100], Loss: 0.05009980872273445
# Validation Accuracy: 0.9
# val_loss, best_loss 0.7478291392326355 0.00010427010420244187
# INFO: Early stopping counter 45 of 45
# INFO: Early stopping
# We are at epoch: 235
# model has been saved at path: CoAtNet_Zoom_36.pkl
